# %%
import pandas as pd 
df = pd.read_excel('../code/clean_monthly/Huong thit final.xlsx')

print(df.columns)
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Mã_tờ_khai', 'Công_ty_nhập',
#        'Công ty nhập gộp', 'Công_ty_nhập (TA)', 'Địa_chỉ', 'Mã_số_thuế',
#        'Nhà_cung_cấp', 'Địa_chỉ_(ncc)', 'Quốc_gia_xuất_xứ',
#        'Mã_nước_xuất_khẩu', 'HScode', 'Mô_tả_sản_phẩm', 'Brand', 'Hợp_lệ',
#        'Updated_Số_lượng', 'Updated_Đơn_vị', 'Số_lượng', 'Đơn_vị',
#        'Khối_lượng', 'Thành_tiền', 'Tiền_tệ', 'Updated_Đơn_giá', 'Đơn_giá',
#        '单价单位', '原单价', 'Tỷ giá', '进口类型', '进口税率', '进口税额', '税额（越南盾)',
#        'Điều_kiện_giao_hàng', '付款方式', '海关名称', '海关代码', '海关代理代码', 'Cảng xuất',
#        '起运港代码', 'Cảng nhập', '目的港代码', '原产国', '原产国家代码', '承运人', '追踪号',
#        'Sản phẩm', 'is_duplicated', 'MarketClassification',
#        'Phân loại công ty nhập'],
#       dtype='object')

# %%
columns_to_select = [
    'Day', 'Month', 'Year', 'Mã_tờ_khai', 'Công_ty_nhập', 'Công ty nhập gộp', 
    'Công_ty_nhập (TA)', 'Địa_chỉ', 'Mã_số_thuế', 'Nhà_cung_cấp', 'Địa_chỉ_(ncc)', 
    'Quốc_gia_xuất_xứ', 'HScode', 'Mô_tả_sản_phẩm', 'Brand', 'Hợp_lệ', 
    'Updated_Số_lượng', 'Updated_Đơn_vị', 'Số_lượng', 'Đơn_vị', 'Khối_lượng', 
    'Thành_tiền', 'Tiền_tệ', 'Updated_Đơn_giá', 'Đơn_giá', 'Tỷ giá', 
    'Điều_kiện_giao_hàng', 'Cảng xuất', 'Cảng nhập', 'MarketClassification', 
    'Phân loại công ty nhập', 'is_duplicated', 'Sản phẩm'
]

new_column_names = [
    'Day', 'Month', 'Year', 'Mã tờ khai', 'Công_ty_nhập', 'Công ty nhập gộp', 
    'Công_ty_nhập (TA)', 'Địa_chỉ', 'Mã số thuế', 'Nhà_cung_cấp', 'Địa_chỉ_(ncc)', 
    'Quốc_gia_xuất_xứ', 'HScode', 'Mô_tả_sản_phẩm', 'Thương hiệu', 'Hợp_lệ', 
    'updated_Số_lượng', 'updated_Đơn_vị', 'Số lượng', 'Đơn_vị', 'Khối_lượng', 
    'Thành_tiền', 'Tiền_tệ', 'Updated_Đơn_giá', 'Đơn_giá', 'Tỷ giá', 
    'Điều_kiện_giao_hàng', 'Cảng xuất', 'Cảng nhập', 'Phân loại thị trường', 
    'Phân loại công ty nhập', 'is_duplicate', 'Sản phẩm'
]

selected_columns_df = df[columns_to_select]
selected_columns_df.columns = new_column_names

print(selected_columns_df)

# %%
columns_to_select = [
    'Day', 'Month', 'Year', 'Mã_tờ_khai', 'Công_ty_nhập', 'Công ty nhập gộp', 
    'Công_ty_nhập (TA)', 'Địa_chỉ', 'Mã_số_thuế', 'Nhà_cung_cấp', 'Địa_chỉ_(ncc)', 
    'Quốc_gia_xuất_xứ', 'HScode', 'Mô_tả_sản_phẩm', 'Brand', 'Hợp_lệ', 
    'Updated_Số_lượng', 'Updated_Đơn_vị', 'Số_lượng', 'Đơn_vị', 'Khối_lượng', 
    'Thành_tiền', 'Tiền_tệ', 'Updated_Đơn_giá', 'Đơn_giá', 'Tỷ giá', 
    'Điều_kiện_giao_hàng', 'Cảng xuất', 'Cảng nhập', 'MarketClassification', 
    'Phân loại công ty nhập', 'is_duplicated', 'Sản phẩm'
]

new_column_names = [
    'Day', 'Month', 'Year', 'Mã tờ khai', 'Công ty nhập', 'Công ty nhập gộp', 
    'Công ty nhập (TA)', 'Địa chỉ', 'Mã số thuế', 'Nhà cung cấp', 'Địa chỉ (ncc)', 
    'Quốc gia xuất xứ', 'HScode', 'Mô tả sản phẩm', 'Thương hiệu', 'Hợp lệ', 
    'updated Số lượng', 'updated Đơn vị', 'Số lượng', 'Đơn vị', 'Khối lượng', 
    'Thành tiền', 'Tiền tệ', 'Updated Đơn giá', 'Đơn giá', 'Tỷ giá', 
    'Điều kiện giao hàng', 'Cảng xuất', 'Cảng nhập', 'Phân loại thị trường', 
    'Phân loại công ty nhập', 'is duplicate', 'Sản phẩm'
]

selected_columns_df = df[columns_to_select]
selected_columns_df.columns = new_column_names

selected_columns_df.to_excel('../code/clean_monthly/Huong thit final selected columns.xlsx', index=False)
print(selected_columns_df)
# Out:
#      Day  Month  Year    Mã tờ khai                             Công ty nhập  \
# 0     29      8  2024  106534677211   CÔNG TY CỔ PHẦN CÔNG NGHỆ PHẨM BA ĐÌNH
# 1     29      8  2024  106534677211   CÔNG TY CỔ PHẦN CÔNG NGHỆ PHẨM BA ĐÌNH
# 2     29      8  2024  106530725820   CÔNG TY CỔ PHẦN CÔNG NGHỆ PHẨM BA ĐÌNH
# 3     29      8  2024  106534677211   CÔNG TY CỔ PHẦN CÔNG NGHỆ PHẨM BA ĐÌNH
# 4     28      8  2024  106532385040   CÔNG TY CỔ PHẦN CÔNG NGHỆ PHẨM BA ĐÌNH
# ..   ...    ...   ...           ...                                      ...
# 541    9      1  2024  106008883150  CÔNG TY TNHH PHỤ GIA THỰC PHẨM VIỆT NAM
# 542    9      1  2024  106008883150  CÔNG TY TNHH PHỤ GIA THỰC PHẨM VIỆT NAM
# 543    8      1  2024  106007287740  CÔNG TY TNHH PHỤ GIA THỰC PHẨM VIỆT NAM
# 544    5      1  2024  105998691850  CÔNG TY TNHH PHỤ GIA THỰC PHẨM VIỆT NAM
# 545    4      1  2024  105994598250  CÔNG TY TNHH PHỤ GIA THỰC PHẨM VIỆT NAM
#
#                Công ty nhập gộp                             Công ty nhập (TA)  \
# 0                       BA ĐÌNH  BA ĐÌNH FOODSTUFF TECHNOLOGY COMPANY LIMITED
# 1                       BA ĐÌNH  BA ĐÌNH FOODSTUFF TECHNOLOGY COMPANY LIMITED
# 2                       BA ĐÌNH  BA ĐÌNH FOODSTUFF TECHNOLOGY COMPANY LIMITED
# 3                       BA ĐÌNH  BA ĐÌNH FOODSTUFF TECHNOLOGY COMPANY LIMITED
# 4                       BA ĐÌNH  BA ĐÌNH FOODSTUFF TECHNOLOGY COMPANY LIMITED
# ..                          ...                                           ...
# 541  PHỤ GIA THỰC PHẨM VIỆT NAM                 VIETNAM FOOD ADDITIVES CO LTD
# 542  PHỤ GIA THỰC PHẨM VIỆT NAM                 VIETNAM FOOD ADDITIVES CO LTD
# 543  PHỤ GIA THỰC PHẨM VIỆT NAM                 VIETNAM FOOD ADDITIVES CO LTD
# 544  PHỤ GIA THỰC PHẨM VIỆT NAM                 VIETNAM FOOD ADDITIVES CO LTD
# 545  PHỤ GIA THỰC PHẨM VIỆT NAM                 VIETNAM FOOD ADDITIVES CO LTD
#
#                                                Địa chỉ  Mã số thuế  \
# 0    Số 39, phố Phó Đức Chính, Phường Trúc Bạch, Qu...   101072018
# 1    Số 39, phố Phó Đức Chính, Phường Trúc Bạch, Qu...   101072018
# 2    Số 39, phố Phó Đức Chính, Phường Trúc Bạch, Qu...   101072018
# 3    Số 39, phố Phó Đức Chính, Phường Trúc Bạch, Qu...   101072018
# 4    Số 39, phố Phó Đức Chính, Phường Trúc Bạch, Qu...   101072018
# ..                                                 ...         ...
# 541  Nhà số 5, ngách 49/16 phố Trần Cung, Phường Ng...   109610652
# 542  Nhà số 5, ngách 49/16 phố Trần Cung, Phường Ng...   109610652
# 543  Nhà số 5, ngách 49/16 phố Trần Cung, Phường Ng...   109610652
# 544  Nhà số 5, ngách 49/16 phố Trần Cung, Phường Ng...   109610652
# 545  Số nhà 5, ngách 49/16 phố Trần Cung, Phường Ng...   109610652
#
#                                 Nhà cung cấp  ... Updated Đơn giá  Đơn giá  \
# 0            XUZHOU HENGXING CHEMICAL CO LTD  ...        1.450000  1450.00
# 1            XUZHOU HENGXING CHEMICAL CO LTD  ...        1.400000  1400.00
# 2                NINGBO WANGLONG TECH CO LTD  ...        2.750000     2.75
# 3            XUZHOU HENGXING CHEMICAL CO LTD  ...        1.530000  1530.00
# 4    GUANGZHOU WEIYA ECONOMIC TRADING CO LTD  ...        2.370000     2.37
# ..                                       ...  ...             ...      ...
# 541      CHINA STAR CHEMICAL COMPANY LIMITED  ...        4.750000     4.75
# 542      CHINA STAR CHEMICAL COMPANY LIMITED  ...        7.280000     7.28
# 543             JINING DEMING TRADING CO LTD  ...        7.121044    13.00
# 544               JINING NATURE FOODS CO LTD  ...        4.800000     4.80
# 545       QINGDAO FOTURE INDUSTRY CO LIMITED  ...        3.100000  3100.00
#
#       Tỷ giá Điều kiện giao hàng Cảng xuất         Cảng nhập  \
# 0    24780.0                 CIF       NaN               NaN
# 1    24780.0                 CIF       NaN               NaN
# 2    24780.0                 FOB       NaN               NaN
# 3    24780.0                 CIF       NaN               NaN
# 4    24780.0                 FOB       NaN               NaN
# ..       ...                 ...       ...               ...
# 541  24190.0                 CIF       NaN               NaN
# 542  24190.0                 CIF       NaN               NaN
# 543  24190.0                 CIF       NaN               NaN
# 544  24060.0                 FOB       NaN               NaN
# 545  24060.0                 CIF   QINGDAO  CANG NAM DINH VU
#
#              Phân loại thị trường Phân loại công ty nhập  is duplicate  \
# 0                             BFC            Thương mại              0
# 1                             BFC            Thương mại              0
# 2                             BFC            Thương mại              0
# 3                             BFC            Thương mại              0
# 4                             BFC            Thương mại              0
# ..                            ...                    ...           ...
# 541  đối thủ cạnh tranh trực tiếp            Thương mại              0
# 542  đối thủ cạnh tranh trực tiếp            Thương mại              0
# 543  đối thủ cạnh tranh trực tiếp            Thương mại              0
# 544  đối thủ cạnh tranh trực tiếp            Thương mại              0
# 545  đối thủ cạnh tranh trực tiếp            Thương mại              0
#
#        Sản phẩm
# 0    Huong thit
# 1    Huong thit
# 2    Huong thit
# 3    Huong thit
# 4    Huong thit
# ..          ...
# 541  Huong thit
# 542  Huong thit
# 543  Huong thit
# 544  Huong thit
# 545  Huong thit
#
# [546 rows x 33 columns]
