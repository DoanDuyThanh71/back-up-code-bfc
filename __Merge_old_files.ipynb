# %%
# %load_ext autoreload
# %autoreload
import pandas as pd
import numpy as np
from merge_files import merge_new_into_old
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# merge_new_into_old("clean_monthly/cleaned_thang_5.xlsx", existedFilePath="merged_files/thang_4/", outputfolder="merged_files/thang_5/")
merge_new_into_old("clean_monthly/file_bo_sung_cac_chat.xlsx", existedFilePath="mnt/c/Users/ndqua/BFC/PowerBI - Cleaning data/", outputfolder="merged_files/thang_1/")
# Out:
# Columns that are unmatched in df:  ()
# 1. Acesulfame k
# This file existed!
# 10. Sorbate
# This file existed!
# 11. Yeast extract
# This file existed!
# 12. Huong thit
# Columns that are unmatched in df:  ('海关代理代码', '海关代码', '目的港代码', 'Số lượng', '海关名称', '承运人', 'Khối_lượng', 'is_duplicate', '原产国', '追踪号', '起运港代码', 'Đơn_vị', '原产国家代码', '税额（越南盾)', '付款方式', 'Sản phẩm')
# Merge successfully! merged_files/thang_5/12. Huong Thit 2020 032024.xlsx
# 13. Sodium dehydroacetate
# This file existed!
# 14. Bột làm thạch
# This file existed!
# 15. Hfcs
# This file existed!
# 16. Gluten
# Columns that are unmatched in df:  ('海关代理代码', '海关代码', '目的港代码', '承运人', 'is_duplicate', '原产国', '追踪号', '起运港代码', '海关名称', '原产国家代码', '税额（越南盾)', '付款方式')
# Merge successfully! merged_files/thang_5/16. Gluten 2020 2024.xlsx
# 17. Soy protein
# Columns that are unmatched in df:  ('海关代理代码', '海关代码', '目的港代码', '承运人', 'is_duplicate', '原产国', '追踪号', '起运港代码', '海关名称', '原产国家代码', '税额（越南盾)', '付款方式', 'Sản phẩm')
# ...
