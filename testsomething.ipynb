# %%
import pandas as pd
df = pd.read_excel('merged_file_thang_5_2024_fix_don_gia_brand.xlsx')
print(df.head())
# Out:
#    Day  Month  Year    Mã tờ khai  \
# 0   31      8  2021  104227247020
# 1   20      2  2023  105279702730
# 2   20      2  2023  105280286860
# 3   20      2  2023  105279702730
# 4   20      2  2023  105279702730
#
#                                         Công_ty_nhập Công ty nhập gộp  \
# 0                      CÔNG TY TNHH THƯƠNG MẠI H B C            H B C
# 1  CÔNG TY TNHH NƯỚC GIẢI KHÁT SUNTORY PEPSICO VI...          PEPSICO
# 2                      CÔNG TY TNHH THƯƠNG MẠI H B C            H B C
# 3  CÔNG TY TNHH NƯỚC GIẢI KHÁT SUNTORY PEPSICO VI...          PEPSICO
# 4  CÔNG TY TNHH NƯỚC GIẢI KHÁT SUNTORY PEPSICO VI...          PEPSICO
#
#                          Công_ty_nhập (TA)  \
# 0            H.B.C TRADING COMPANY LIMITED
# 1  SUNTORY PEPSICO VIETNAM BEVERAGE CO LTD
# 2            H B C TRADING COMPANY LIMITED
# 3  SUNTORY PEPSICO VIETNAM BEVERAGE CO LTD
# 4  SUNTORY PEPSICO VIETNAM BEVERAGE CO LTD
#
# ...

# %%
supplier_names = df['Nhà_cung_cấp'].unique()
supplier_names = sorted(map(str, supplier_names))
print(supplier_names)

# Convert the list to a DataFrame
supplier_names_df = pd.DataFrame(supplier_names, columns=['Nhà_cung_cấp'])

# Export data to a new file with the same 'Mã số thuế' column
supplier_names_df.to_excel('output_file.xlsx', index=False)
print("Data exported successfully to 'output_file.xlsx'")
# Out:
# ['190 73', '2 CONNECT APS', '2BKO CO LTD', '2LIANS RECYCLING PTE LTD', '2M INTERNATIONAL GMBH', '3A SHANGHAI LIFE SCIENCE CO LTD', '3D BEST CONNECT CO LTD', '3D SYSTEMS ASIA PACIFIC PTY LTD', '3E CHEMICAL SUZHOU CO LTD', '3G WIRELESS', '3M APAC RDC PTE LTD', '3M COMPANY', '3S ANALYZERS S R L', 'A A LINK PTY LTD', 'A B SHIN HAI 26 LTD', 'A B VICKERS  LALLEMAND UK LTD', 'A COSTANTINO C SPA', 'A FIVE ECOMMERCE LLC', 'A G GILRO LTD', 'A H A INTERNATIONAL CO LTD', 'A M FOOD CHEMICAL CO LIMITED', 'A M TECHNOLOGY CO LTD', 'A P I ZINC PLATING CO LTD', 'A P PHARMACEUTICALS INC', 'A PLUS SUPPLY CO LTD', 'A V IMPORT EXPORT', 'A WELL INGREDIENTS CO LTD', 'A2B GMBH', 'A2E IMPORT EXPORT CO LTD', 'AAFUD INDUSTRY ZHUHAI CO LTD', 'AARON BLAKE', 'AARON INTERNATIONAL LTD', 'AARON TRADE CO LTD', 'AB MEDICAL INC', 'AB SCIEX THAILAND COMPANY LIMITED', 'ABB LTD', 'ABB POWER GRIDS SWEDEN AB', 'ABB TRADING PTY LTD', 'ABB XIAMEN LOW VOLTAGE EQUIPMENT CO LTD', 'ABBEYLANDS FURNITURE NAVAN LTD', 'ABBOTT LABORATO
# ...

# %%
# Thương hiệu NANTONG
supplier_names_to_replace = [
    "NANTONG ACETIC ACID CHEMICAL CO LT",
    "NANTONG ACETIC ACID CHEMICAL CO LTD",
    "NANTONG ALCHEMY BIOTECH DEVELOPMENT CO LTD",
    "NANTONG BOMEI INTERNATIONAL TRADING CO LTD",
    "NANTONG CHANGHAI FOOD ADDITIVE",
    "NANTONG CHANGHAI FOOD ADDITIVE CO",
    "NANTONG CHANGHAI FOOD ADDITIVE CO LTD",
    "NANTONG CHANGJIANG FOOD INGREDIENT LTD",
    "NANTONG LAIKA MECHANICAL EQUIPMENT CO LTD",
    "NANTONG WENAO IMPORT AND EXPORT CO LTD",
    "NANTONG XIQI TEXTILE CO LTD",
    "NANTONG YUWON INTELLIGENT EQUIPMENT CO LTD",
    "NANTONG ZHUANGYUE TRADE CO LTD"
]

# Replace the supplier names in the 'Nhà_cung_cấp' column
df['Nhà_cung_cấp'] = df['Nhà_cung_cấp'].replace(supplier_names_to_replace, 'NANTONG')
print(df['Nhà_cung_cấp'].unique())

# %%
# List of supplier names to replace with 'QINGDAO'
supplier_names_to_replace_qingdao = [
    "QINGDAO TONGLIAN INTERNATIONAL TRADE CO LTD",
    "QINGDAO JIUTAI BIOTECHNOLOGY CO LTD",
    "QINGDAO REEGO GROUP LIMITED",
    "QINGDAO ZILLIONAIRE CHEMICALS INC",
    "QINGDAO AMBERS CHEMICAL TECHNOLOGY CO LTD",
    "QINGDAO ARTIFICIAL CASING CO LTD",
    "QINGDAO ASPIRIT CHEMICAL CO LTD",
    "QINGDAO AURICA IMP EXP CO LTD",
    "QINGDAO BAOLINGBAO IMPORT EXPORT CO LTD",
    "QINGDAO BESTYDECOR CO LTD",
    "QINGDAO BNP BIOSCIENCE CO LTD",
    "QINGDAO BNP BIOSCIENCE INC",
    "QINGDAO BOLI INTERNATIONAL CO LTD",
    "QINGDAO BRIGHT MOON SEAWEED GROUP",
    "QINGDAO BRIGHT MOON SEAWEED GROUP C",
    "QINGDAO BRIGHT MOON SEAWEED GROUP CO LTD",
    "QINGDAO CLEANHEALTH PROTECTIVE ARTICLES CO LTD",
    "QINGDAO CPI INTERNATIONAL CO LTD",
    "QINGDAO CROWN IMP EXP CORP LTD",
    "QINGDAO DEFENG CEREAL TRADING CO LTD",
    "QINGDAO DEFENG CEREALTRADING CO LTD",
    "QINGDAO DERUN CHEMICAL CO LTD",
    "QINGDAO DOEAST CHEMICAL CO LTD",
    "QINGDAO DOEAST CHEMICAL INC",
    "QINGDAO ECHEMI TECHNOLOGY CO LTD",
    "QINGDAO ESSENLAND BIOTECH CO LTD",
    "QINGDAO EVER EXCEED IMP EXP CO LTD",
    "QINGDAO EVER TRUST BIOTECH CO LTD",
    "QINGDAO FENGRUN SEAWEED CO LTD",
    "QINGDAO FOREVER RICH CHEMICAL TECHNOLOGY CO LTD",
    "QINGDAO SHENGDA COMMERCIALAND TRADE CO LTD",
    "QINGDAO SHENGLONG XINDE IMP AND EXP CO LTD",
    "QINGDAO SHENGTAI TRADING CO LTD",
    "QINGDAO SHENGTONG EVER TRADE IMPORT AND EXPORT CO LTD",
    "QINGDAO SHENGTONG EVER TRADE IMPORT EXPORT CO LTD",
    "QINGDAO SHETONG EVER TRADE IMPORT EXPORT CO LTD",
    "QINGDAO SHILIAN",
    "QINGDAO SINGSINO GROUP LIMITED",
    "QINGDAO SINOCMC CHEMICAL CO LTD",
    "QINGDAO STANTI INTERNATIONAL TRADE CO LTD",
    "QINGDAO SUNMART HOMEWARE CO LTD",
    "QINGDAO SYNVELOP INTERNATIONAL TRADE CO LTD",
    "QINGDAO TAOSIGN INTERNATIONAL TRADE",
    "QINGDAO TAOSIGN INTERNATIONAL TRADE CO LIMITED",
    "QINGDAO TERIO CORPORATION",
    "QINGDAO TO ORDER BIOLOGY TECH CO LTD",
    "QINGDAO TONGLI UNITED CO LTD",
    "QINGDAO TONGLIAN INTERNATIONAL TRADE CO LTD",
    "QINGDAO TONGLIAN INTERNATIONAL TRADE CO LTD  ",
    "QINGDAO UNIONCHEM CO LTD",
    "QINGDAO UNITED INTERNATIONAL CO L",
    "QINGDAO VLAND BIOCHEM CO LTD",
    "QINGDAO WANTUMING BIOLOGICAL PRODUCTS CO LTD",
    "QINGDAO WELLENCE INTERNATIONAL TRADING CO LTD",
    "QINGDAO XINYIUAN INTERNATIONAL IMPORT AND EXPORT CO LTD",
    "QINGDAO XINYIYUAN INTERNATIONAL IMPORT AND EXPORT CO LTD",
    "QINGDAO YESHANG TRADING CO LTD",
    "QINGDAO YINGFEI CHEMICAL CO LTD",
    "QINGDAO Z AND F SUNGOLD",
    "QINGDAO Z AND F SUNGOLD INTERNATIONAL TRADE CO LTD",
    "QINGDAO Z F SUNGOLD INTERNATIONAL TRADE CO LTD",
    "QINGDAO Z F SUNGOLD INTERNATIONALTRADE CO LTD",
    "QINGDAO ZEFENG SEAWEED CHEMICAL CO LTD",
    "QINGDAO ZHENGTAIXIN TRADE CO LTD"
]

# Replace the supplier names in the 'Nhà_cung_cấp' column
df['Nhà_cung_cấp'] = df['Nhà_cung_cấp'].replace(supplier_names_to_replace_qingdao, 'QINGDAO')
print(df['Nhà_cung_cấp'].unique())
# Out:
# ['TORONTO RESEARCH CHEMICALS INC' 'PEPSICO BEVERAGE SINGAPORE PTY LTD'
#  'LGC STANDARDS GMBH' ... 'SUZHOU EASTMATE IMP EXP CO LTD'
#  'ZHENGZHOU ZHONGYUAN DISTRICT TANGGE KONJAC MACHINERY FACTORY'
#  'ALDEN CHEE']

# %%
# Replace "SINOSWEET CO LTD" with "sinosweet" in the 'Nhà_cung_cấp' column
df['Nhà_cung_cấp'] = df['Nhà_cung_cấp'].replace("SINOSWEET CO LTD", "SINOSWEET")
print(df['Nhà_cung_cấp'].unique())
